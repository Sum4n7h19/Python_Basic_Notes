# %% [markdown]
# <div style='background:#B1F9E3; color:#000000' class='alert alert-box'>
#   <h1>Input and Output in Pandas</h1>
# </div>

# %%
# Importing pandas and numpy
import numpy as np
import pandas as pd
import requests

# %%
# Passing online url as data
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
url
# Out:
# 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Export dataframe to csv
df.to_csv('titanic.csv')

# %%
# Exporting dataframe with limited columns
df.to_csv('titanic1.csv',columns=['Survived','Name','Age'])

# %%
# Exporting without index
df.to_csv('titanic2.csv', index = False)

# %%
# Working with excel file
# xls and xlsx
# module check xlrd and openpyxl
# !conda list
# Out:
# # packages in environment at C:\Users\wwwsu\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2023.09             py311_mkl_1
# abseil-cpp                20211102.0           hd77b12b_0
# aiobotocore               2.7.0           py311haa95532_0
# aiohttp                   3.9.0           py311h2bbff1b_0
# aioitertools              0.7.1              pyhd3eb1b0_0
# aiosignal                 1.2.0              pyhd3eb1b0_0
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda-anon-usage       0.4.3           py311hfc23b7f_100
# anaconda-catalogs         0.2.0           py311haa95532_0
# anaconda-client           1.12.2          py311haa95532_0
# anaconda-cloud-auth       0.1.4           py311haa95532_0
# anaconda-navigator        2.5.1           py311haa95532_0
# anaconda-project          0.11.1          py311haa95532_0
# anyio                     3.5.0           py311haa95532_0
# ...

# %%
# !pip install xlrd

# %%
# Importing pandas and numpy
import numpy as np
import pandas as pd

# %%
#pd.read_excel(#FileName.xls)

# %%
# Reading a excel with specific sheet no
#pd.read_excel('Filename.xlsx',sheet_name=1)
